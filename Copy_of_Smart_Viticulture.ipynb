# %% [markdown]
# <a href="https://colab.research.google.com/github/david0891/Kamran0153.github.io/blob/main/Copy_of_Smart_Viticulture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --upgrade git+https://github.com/NERC-FSF/FieldSpecUtils.git
# Out:
# ...
#   Cloning https://github.com/NERC-FSF/FieldSpecUtils.git to /tmp/pip-req-build-s5zn7qci
#   Running command git clone --filter=blob:none --quiet https://github.com/NERC-FSF/FieldSpecUtils.git /tmp/pip-req-build-s5zn7qci
#   Resolved https://github.com/NERC-FSF/FieldSpecUtils.git to commit 2be4d943ba79c93486ce17dfd632aeb63ab2babf
#   Preparing metadata (setup.py) ... done
# ...

# %%
# Read SVC spectral files
# !pip install --upgrade git+https://github.com/NERC-FSF/SpecDAL.git

# Spectral indices and sensor resampling
# !pip install --upgrade git+https://github.com/NERC-FSF/FieldSpecUtils.git

# PROSAIL canopy simulations
#!pip install pyprosail
#!easy_install pyprosail
# !pip install prosail
# Out:
# ...
#   Cloning https://github.com/NERC-FSF/SpecDAL.git to /tmp/pip-req-build-jtly_tq6
#   Running command git clone --filter=blob:none --quiet https://github.com/NERC-FSF/SpecDAL.git /tmp/pip-req-build-jtly_tq6
#   Resolved https://github.com/NERC-FSF/SpecDAL.git to commit 1b8aa4b91ab66f7b6ef367155eb209c631b62447
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/NERC-FSF/FieldSpecUtils.git to /tmp/pip-req-build-5iqr6bal
#   Running command git clone --filter=blob:none --quiet https://github.com/NERC-FSF/FieldSpecUtils.git /tmp/pip-req-build-5iqr6bal
#   Resolved https://github.com/NERC-FSF/FieldSpecUtils.git to commit 2be4d943ba79c93486ce17dfd632aeb63ab2babf
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.3/149.3 kB 4.4 MB/s eta 0:00:00
# ...

# %%
import specdal
import prosail

print("SpecDAL installed")
print("PROSAIL installed")
# Out:
# SpecDAL installed
# PROSAIL installed

# %%
import FieldSpecUtils

# %%
import specdal
import prosail
